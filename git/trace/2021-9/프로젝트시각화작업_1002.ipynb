# %%
import pandas as pd
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt
# plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.family']='Malgun Gothic'  # Windows
import matplotlib.ticker as mticker
# plt.style.use("seaborn-pastel")
# plt.style.use("seaborn")

# %%
# df_jeju_casino = df_industry_jeju[
#     df_industry_jeju['업종명']=='기타 갬블링 및 베팅업'
# ]

# plt.figure(figsize=(10,5))
# plt.ticklabel_format(style='plain', useOffset=False, )
# plt.xticks(np.arange(2017, 2021, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))

ax = sns.barplot(x='연도', 
                 y='매장수대비이용금액', 
                 data=df_jeju_casino, 
                 palette='YlGn')
ax.set_title('제주시 연도별 갬블링 및 베팅업 매장수대비이용금액')

# %%
plt.rcParams['font.family'] = 'NanumGothic'

# %%
# %ls

# %%
df = pd.read_csv('jupyter/district_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  \
# 0           0  2017  강남구  350     3   115   407    51        48.9       55
# 1           1  2017  강동구  194     6    65   185    15        50.8       22
# 2           2  2017  강북구  271     0    88   291    22        47.8       13
# 3           3  2017  강서구  230     1    72   258    30        48.4       24
# 4           4  2017  관악구  258     1    73   247    35        48.7       23
#
#    출퇴근시간_사고수  이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 0         66        6         48  561052   255025    16714    72511   679047
# 1         50        3         28  440359   153054    16496    29952   146512
# 2         76       15         33  328002    99742    21922    18928    71752
# 3         64        7         30  608255   220758    18695    36556   234394
# 4         50       15         36  520929   146633    24530    26374   115390
#
#    숙박_음식업_사업체수  숙박_음식업_종사자수
# 0        11074        56982
# 1         4885        15466
# 2         3681        10569
# 3         5651        20057
# 4         5640        17322

# %% [markdown]
# ## 지차체별 3년 음주 운전수 누적

# %%
df_alco=pd.pivot_table(data=df, 
               index='자치구', 
               values='음주운전사고수',
               aggfunc='sum').reset_index()

# %%
df_alco = df_alco.reindex(df_alco['음주운전사고수'].sort_values(ascending=False).index)

# %%
plt.figure(figsize=(15,8))

ax = sns.barplot(x='자치구', 
                 y='음주운전사고수', 
                 data=df_alco, 
                 palette='YlGn')
ax.set_title('지차체별 3년 음주 운전수 누적')
# Out:
# Text(0.5, 1.0, '지차체별 3년 음주 운전수 누적')

# %%
df_ja=pd.pivot_table(data=df, 
               index='자치구', 
               values='사고수',
               aggfunc='sum').reset_index()

# %%
df_ja.head(1)
# Out:
#    자치구   사고수
# 0  강남구  1059

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='자치구', y='사고수', data=df_ja, ci=None)
# Out:
# <AxesSubplot:xlabel='자치구', ylabel='사고수'>

# %%
df_sago = df_sago.reindex(df_sago['사고수'].sort_values(ascending=False).index)

# %% [markdown]
# ## 지자체별 3년 사고수 누적

# %%
plt.figure(figsize=(15,8))

ax = sns.barplot(x='자치구', 
                 y='사고수', 
                 data=df_sago, 
                 palette='YlGn')
ax.set_title('지자체별 3년 사고수 누적')
# Out:
# Text(0.5, 1.0, '지자체별 3년 사고수 누적')

# %%
# In [1]: df = pd.DataFrame.from_dict([{'Country': 'A', 'Year':2012, 'Value': 20, 'Volume': 1}, {'Country': 'B', 'Year':2012, 'Value': 100, 'Volume': 2}, {'Country': 'C', 'Year':2013, 'Value': 40, 'Volume': 4}])

# In [2]: df_pivot = pd.pivot_table(df, index=['Country'], columns = ['Year'],values=['Value'], fill_value=0)

# In [3]: df_pivot
# Out [4]:
#     Value     
# Year     2012 2013
# Country           
# A          20    0
# B         100    0
# C           0   40

df_sago = df_sago.reindex(df_sago['사고수'].sort_values(ascending=False).index)

# %%
## 자치구별 분석

# %%
plt.figure(figsize=(15,8))

ax = sns.barplot(x='자치구', 
                 y='사고수', 
                 data=df_sago, 
                 palette='YlGn')
ax.set_title('3년 사고수 누적')

# %%
df_sago=pd.pivot_table(data=df, 
               index='년도', 
               values='사고수',
               aggfunc='sum').reset_index()

# %% [markdown]
# ## 3년 사고수 누적

# %%
plt.figure(figsize=(8,6))

ax = sns.barplot(x='년도', 
                 y='사고수', 
                 data=df_sago, 
                 palette='YlGn')
ax.set_title('3년 사고수 누적')
# Out:
# Text(0.5, 1.0, '3년 사고수 누적')

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x='년도', y='사고수', data=df_sago, ci=None)
# Out:
# <AxesSubplot:xlabel='년도', ylabel='사고수'>

# %%
# plt.figure(figsize=(12,5))
# sns.lineplot(x='연도', y='매장수', data=df_industry, hue='업종명 대분류')

# %% [markdown]
# ## 상관관계 분석

# %%
df2=df.drop(columns='자치구')

# %%
colormap = plt.cm.PuBu

plt.figure(figsize=(20, 20))

plt.title("교통 상관관계를 알아보자", y = 1.05, size = 15)

sns.heatmap(df2.astype(float).corr(), linewidths = 0.1, vmax = 1.0, square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 16})

# 출처: https://hong-yp-ml-records.tistory.com/33 [HONG YP's Data Science BLOG]
# Out:
# <AxesSubplot:title={'center':'교통 상관관계를 알아보자'}>

# %%
import numpy as np

# %%
df__ = df.corr()
# 그림 사이즈 지정
fig, ax = plt.subplots( figsize=(15,12) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(df__, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵을 그린다
sns.heatmap(df__, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()
# Out:
# C:\Users\cityo\AppData\Local\Temp/ipykernel_24204/2361611542.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(df__, dtype=np.bool)

# %%
# df_store_expense_year = df_card.groupby(['연도',  
#                                     '시도명', 
#                                     '업종명 대분류', 
#                                     '업종명'
#                                    ])[['이용금액']].mean().reset_index()
# df_store_count_year = df_card.groupby(['연도', 
#                                   '시도명', 
#                                   '업종명 대분류', 
#                                   '업종명'
#                                  ])[['매장수']].mean().reset_index()

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x='연도', y='매장수', data=df_industry, hue='업종명 대분류')

# %%
df_group.columns
# Out:
# Index(['Unnamed: 0', '년도', '사고수', '사망자수', '중상자수', '경상자수', '부상자수', '사고운전자_평균연령',
#        '음주운전사고수', '출퇴근시간_사고수', '이륜차_사고수', '고령운전자_사고수', '등록인구', '전체차량_대수',
#        '이륜차량_대수', '전체_사업체수', '전체_종사자수', '숙박_음식업_사업체수', '숙박_음식업_종사자수'],
#       dtype='object')

# %%
df[['년도','자치구','사고수']].sort_values(by='년도',ascending=False)
# Out:
#       년도  자치구  사고수
# 74  2019  중랑구  267
# 62  2019  마포구  245
# 50  2019  강남구  349
# 51  2019  강동구  205
# 52  2019  강북구  252
# ..   ...  ...  ...
# 21  2017  은평구  204
# 22  2017  종로구  299
# 23  2017   중구  330
# 24  2017  중랑구  325
# 0   2017  강남구  350
#
# [75 rows x 3 columns]

# %%
# Out:
#    Unnamed: 0    년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  \
# 0           0  2017  강남구  350     3   115   407    51        48.9       55
# 1           1  2017  강동구  194     6    65   185    15        50.8       22
# 2           2  2017  강북구  271     0    88   291    22        47.8       13
# 3           3  2017  강서구  230     1    72   258    30        48.4       24
# 4           4  2017  관악구  258     1    73   247    35        48.7       23
#
#    출퇴근시간_사고수  이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 0         66        6         48  561052   255025    16714    72511   679047
# 1         50        3         28  440359   153054    16496    29952   146512
# 2         76       15         33  328002    99742    21922    18928    71752
# 3         64        7         30  608255   220758    18695    36556   234394
# 4         50       15         36  520929   146633    24530    26374   115390
#
#    숙박_음식업_사업체수  숙박_음식업_종사자수
# 0        11074        56982
# 1         4885        15466
# 2         3681        10569
# 3         5651        20057
# 4         5640        17322

# %%
df2=df.drop(columns='자치구')

# %%
df2_list=df2.columns.tolist()

# %%
df_all=pd.pivot_table(data=df, 
               index='자치구', 
               values=df2_list,
               aggfunc='sum').reset_index()

# %%
list_gu=df_all['자치구']

# %%
list_gu
# Out:
# 0      강남구
# 1      강동구
# 2      강북구
# 3      강서구
# 4      관악구
# 5      광진구
# 6      구로구
# 7      금천구
# 8      노원구
# 9      도봉구
# 10    동대문구
# 11     동작구
# 12     마포구
# 13    서대문구
# 14     서초구
# 15     성동구
# 16     성북구
# 17     송파구
# 18     양천구
# 19    영등포구
# 20     용산구
# 21     은평구
# 22     종로구
# 23      중구
# 24     중랑구
# Name: 자치구, dtype: object

# %%
df_all[df_all['자치구']=='강남구']
# Out:
#    자치구  Unnamed: 0  경상자수  고령운전자_사고수    년도     등록인구  부상자수   사고수  사고운전자_평균연령  \
# 0  강남구          75  1256        157  6054  1658714   142  1059       145.4
#
#    사망자수  숙박_음식업_사업체수  숙박_음식업_종사자수  음주운전사고수  이륜차_사고수  이륜차량_대수  전체_사업체수  \
# 0     6        32841       174705      134       20    50581   214911
#
#    전체_종사자수  전체차량_대수  중상자수  출퇴근시간_사고수
# 0  2072023   759647   262        198

# %%
# list_n=[]

# for i in range(1,25):
    
#     list_n.append(i)
    
# list_n

# %%
# a=0

# for i,x in enumerate(list_gu, 1):

#     df_x = df[df['자치구']==i][['자치구','사고수']]

#     df_1

# %%
df=df.drop(columns='Unnamed: 0',axis=1)

# %%
df_gangnam=df[df['자치구']=='강남구'][:]

# %%
df_gangnam
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 0   2017  강남구  350     3   115   407    51        48.9       55         66
# 25  2018  강남구  360     2    71   439    49        48.9       43         74
# 50  2019  강남구  349     1    76   410    42        47.6       36         58
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 0         6         48  561052   255025    16714    72511   679047
# 25        6         64  547453   252122    16795    71373   694136
# 50        8         45  550209   252500    17072    71027   698840
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 0         11074        56982
# 25        10730        58366
# 50        11037        59357

# %%
plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_gang,  ci=None, palette='Greens_r')
ax.set_title('3년 강남구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 강남구 사고수 변화')

# %%
df_gangseo=df[df['자치구']=='강서구'][:]

# %%
df_gangseo
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 3   2017  강서구  230     1    72   258    30        48.4       24         64
# 28  2018  강서구  268     2   101   345    33        48.5       31         66
# 53  2019  강서구  262     3    77   289    25        51.6       15         60
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 3         7         30  608255   220758    18695    36556   234394
# 28        6         33  603611   223157    18542    38524   248204
# 53        9         46  598273   223476    18652    39458   257494
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 3          5651        20057
# 28         5900        21475
# 53         6106        22192

# %%
df_gangseo

plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_gangseo,  ci=None, palette='Greens_r')
ax.set_title('3년 강서구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 강서구 사고수 변화')

# %%
df_mapo=df[df['자치구']=='마포구'][:]

# %%
df_mapo
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 12  2017  마포구  299     3    74   379    20        47.1       29         59
# 37  2018  마포구  283     1    83   330    24        48.4       25         76
# 62  2019  마포구  245     1    58   282    45        48.2       20         46
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 12        4         43  385783   133818    17287    36325   247999
# 37        2         37  386359   135066    17075    37232   255152
# 62        2         34  385925   135135    17228    37290   247276
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 12         8139        28793
# 37         8429        31288
# 62         8616        29425

# %%
df_mapo=df[df['자치구']=='마포구'][['년도','자치구','사고수']]

plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_mapo,  ci=None, palette='Greens_r')
ax.set_title('3년 마포구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 마포구 사고수 변화')

# %%
df_yeong=df[df['자치구']=='영등포구'][:]

# %%
df_yeong
# Out:
#       년도   자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 19  2017  영등포구  373     2   105   426    62        49.7       28         86
# 44  2018  영등포구  381     5    94   438    49        49.3       30         78
# 69  2019  영등포구  325     1    77   348    44        50.8       15         73
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 19       13         59  402024   162628    16478    43163   362800
# 44        8         53  403600   160301    16361    42589   367557
# 69       11         54  400986   158273    16263    42370   373478
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 19         7003        25853
# 44         6897        27163
# 69         6954        27259

# %%
df_yeong=df[df['자치구']=='영등포구'][['년도','자치구','사고수']]

plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_yeong,  ci=None, palette='Greens_r')
ax.set_title('3년 영등포구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 영등포구 사고수 변화')

# %%
df_jong=df[df['자치구']=='종로구'][:]

# %%
df_jong
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 22  2017  종로구  299     5    99   303    56        51.5       18         59
# 47  2018  종로구  269     0    66   270    39        53.1       21         52
# 72  2019  종로구  275     2    91   278    51        50.3       16         66
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 22        8         48  164257    64216    13388    40490   268702
# 47        7         52  163026    63883    13151    39952   265017
# 72       12         53  161869    63321    13269    39679   260446
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 22         6724        26577
# 47         6625        27639
# 72         6709        26606

# %%
df_jong=df[df['자치구']=='종로구'][['년도','자치구','사고수']]

plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_jong,  ci=None, palette='Greens_r')
ax.set_title('3년 종로구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 종로구 사고수 변화')

# %%
list_gu
# Out:
# 0      강남구
# 1      강동구
# 2      강북구
# 3      강서구
# 4      관악구
# 5      광진구
# 6      구로구
# 7      금천구
# 8      노원구
# 9      도봉구
# 10    동대문구
# 11     동작구
# 12     마포구
# 13    서대문구
# 14     서초구
# 15     성동구
# 16     성북구
# 17     송파구
# 18     양천구
# 19    영등포구
# 20     용산구
# 21     은평구
# 22     종로구
# 23      중구
# 24     중랑구
# Name: 자치구, dtype: object

# %%
df_gdong=df[df['자치구']=='강동구'][:]

# %%
df_gdong
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 1   2017  강동구  194     6    65   185    15        50.8       22         50
# 26  2018  강동구  226     1    64   216    27        51.5       16         49
# 51  2019  강동구  205     2    70   205    21        50.6       10         51
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 1         3         28  440359   153054    16496    29952   146512
# 26        5         39  431920   151739    16305    29772   145990
# 51        3         29  440390   156231    16668    29080   141770
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 1          4885        15466
# 26         4834        15308
# 51         4879        15636

# %%
df_gdong=df[df['자치구']=='강동구'][['년도','자치구','사고수']]

plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_gdong,  ci=None, palette='Greens_r')
ax.set_title('3년 강동구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 강동구 사고수 변화')

# %%
df_nowon=df[df['자치구']=='노원구'][:]

# %%
df_nowon
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 8   2017  노원구  264     1    67   309    34        48.6       24         77
# 33  2018  노원구  251     2    71   303    21        50.8       27         42
# 58  2019  노원구  260     2    69   291    23        49.8       14         66
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 8         7         34  558075   169700    14992    26516   117859
# 33        4         36  548160   168581    14957    26616   118713
# 58        4         49  537303   166980    14905    26618   116684
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 8          4143        14211
# 33         4191        14443
# 58         4278        14520

# %%
df_nowon=df[df['자치구']=='노원구'][['년도','자치구','사고수']]

plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_nowon,  ci=None, palette='Greens_r')
ax.set_title('3년 노원구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 노원구 사고수 변화')

# %%
df_gbook=df[df['자치구']=='강북구'][:]

# %%
df_gbook
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 2   2017  강북구  271     0    88   291    22        47.8       13         76
# 27  2018  강북구  258     1    70   297    13        49.7       14         56
# 52  2019  강북구  252     1    57   269    14        50.1       10         56
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 2        15         33  328002    99742    21922    18928    71752
# 27       10         36  322915    99147    21782    18918    72418
# 52       23         48  317695    98254    21890    19014    73904
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 2          3681        10569
# 27         3719        10674
# 52         3779        11090

# %%
df_gbook=df[df['자치구']=='강북구'][['년도','자치구','사고수']]

plt.figure(figsize=(12,5))
plt.ticklabel_format(style='plain', useOffset=False, )
plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='사고수', data=df_gbook,  ci=None, palette='Greens_r')
ax.set_title('3년 강북구 사고수 변화')
# Out:
# Text(0.5, 1.0, '3년 강북구 사고수 변화')

# %%
df
# Out:
#     Unnamed: 0    년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  \
# 0            0  2017  강남구  350     3   115   407    51        48.9       55
# 1            1  2017  강동구  194     6    65   185    15        50.8       22
# 2            2  2017  강북구  271     0    88   291    22        47.8       13
# 3            3  2017  강서구  230     1    72   258    30        48.4       24
# 4            4  2017  관악구  258     1    73   247    35        48.7       23
# ..         ...   ...  ...  ...   ...   ...   ...   ...         ...      ...
# 70          70  2019  용산구  235     0    56   255    12        49.8       14
# 71          71  2019  은평구  199     1    73   191    26        52.5       16
# 72          72  2019  종로구  275     2    91   278    51        50.3       16
# 73          73  2019   중구  270     1    79   267    27        51.1        7
# 74          74  2019  중랑구  267     2    76   256    29        51.3       10
#
#     출퇴근시간_사고수  이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 0          66        6         48  561052   255025    16714    72511   679047
# 1          50        3         28  440359   153054    16496    29952   146512
# 2          76       15         33  328002    99742    21922    18928    71752
# 3          64        7         30  608255   220758    18695    36556   234394
# 4          50       15         36  520929   146633    24530    26374   115390
# ..        ...      ...        ...     ...      ...      ...      ...      ...
# 70         47       10         41  245185    92666    16145    20254   135240
# 71         49        5         38  484546   150700    20880    24681    93631
# 72         66       12         53  161869    63321    13269    39679   260446
# 73         57        7         54  136488    66089    14353    60127   392568
# 74         65       18         47  402024   137050    24327    28228   103345
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 0         11074        56982
# 1          4885        15466
# 2          3681        10569
# 3          5651        20057
# 4          5640        17322
# ..          ...          ...
# 70         4594        18282
# 71         4331        12965
# 72         6709        26606
# 73         6250        34751
# 74         4171        11311
#
# [75 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '년도', '자치구', '사고수', '사망자수', '중상자수', '경상자수', '부상자수',
#        '사고운전자_평균연령', '음주운전사고수', '출퇴근시간_사고수', '이륜차_사고수', '고령운전자_사고수', '등록인구',
#        '전체차량_대수', '이륜차량_대수', '전체_사업체수', '전체_종사자수', '숙박_음식업_사업체수',
#        '숙박_음식업_종사자수'],
#       dtype='object')

# %%
df_gangseo=df[df['자치구']=='강서구'][['년도', '자치구', '사고수', '사망자수', '중상자수', '경상자수', '부상자수',
       '사고운전자_평균연령', '음주운전사고수', '출퇴근시간_사고수', '이륜차_사고수', '고령운전자_사고수', '등록인구',
       '전체차량_대수', '이륜차량_대수', '전체_사업체수', '전체_종사자수', '숙박_음식업_사업체수',
       '숙박_음식업_종사자수']]

# %%
df_gangseo
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 3   2017  강서구  230     1    72   258    30        48.4       24         64
# 28  2018  강서구  268     2   101   345    33        48.5       31         66
# 53  2019  강서구  262     3    77   289    25        51.6       15         60
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 3         7         30  608255   220758    18695    36556   234394
# 28        6         33  603611   223157    18542    38524   248204
# 53        9         46  598273   223476    18652    39458   257494
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 3          5651        20057
# 28         5900        21475
# 53         6106        22192

# %%
plt.figure(figsize=(12,6))
plt.ticklabel_format(style='plain', useOffset=False, )
# plt.xticks(np.arange(2017, 2020, step=1))
# plt.gca().yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f원'))
ax = sns.lineplot(x='년도', y='등록인구', data=df_gangseo,  ci=None, palette='Greens_r')
ax.set_title('3년 강서구 등록인구수 변화')
# Out:
# Text(0.5, 1.0, '3년 강서구 등록인구수 변화')

# %%
# a=0

# for i in list_gu:

#     df_a = df[df['자치구']==i][['자치구','사고수']]
#     a+=1
    
    
# df_a
# Out:
#     자치구  사고수
# 24  중랑구  325
# 49  중랑구  280
# 74  중랑구  267

# %%
df['자치구'].nunique()
# Out:
# 25

# %%
df['자치구'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
강서,강북,노원,강동,종로,영등,마포,강서,강남

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df_gwang=df[df['자치구']=='광진구'][:]
df_gwan=df[df['자치구']=='관악구'][:]
df_guro=df[df['자치구']=='구로구'][:]
df_gold=df[df['자치구']=='금천구'][:]
df_jung=df[df['자치구']=='중랑구'][:]
df_eun=df[df['자치구']=='은평구'][:]
df_seong=df[df['자치구']=='성북구'][:]
df_yong=df[df['자치구']=='용산구'][:]
df_dong=df[df['자치구']=='동대문구'][:]
df_seo=df[df['자치구']=='서대문구'][:]
df_moving=df[df['자치구']=='동작구'][:]
df_do=df[df['자치구']=='도봉구'][:]
df_sung=df[df['자치구']=='성동구'][:]
df_jjung=df[df['자치구']=='중랑구'][:]
df_yang=df[df['자치구']=='양천구'][:]

# %%
df_gwang
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 5   2017  광진구  230     0    80   223    31        48.7       14         58
# 30  2018  광진구  258     2    85   250    15        49.4       26         58
# 55  2019  광진구  212     0    53   253    11        49.7       13         34
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 5         4         32  372298   117082    18451    24688   125170
# 30        7         35  371063   118893    18341    24535   127879
# 55        9         36  366972   117576    18277    24445   126305
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 5          4675        16498
# 30         4764        17023
# 55         4786        16639

# %%
df_gwan
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 4   2017  관악구  258     1    73   247    35        48.7       23         50
# 29  2018  관악구  285     0    91   287    33        48.4       22         66
# 54  2019  관악구  286     0    88   252    23        50.3       20         62
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 4        15         36  520929   146633    24530    26374   115390
# 29       13         35  520040   145944    24514    26105   113944
# 54       17         54  517334   144565    24515    25505   115329
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 4          5640        17322
# 29         5561        17541
# 54         5662        17812

# %%
df_guro
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 6   2017  구로구  271     2    90   281    22        49.1       28         47
# 31  2018  구로구  282     1    71   325    28        48.9       17         64
# 56  2019  구로구  257     2    79   294    22        49.2       17         75
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 6        14         39  441559   160214    16254    38405   213468
# 31       11         29  438486   160284    15844    38553   218070
# 56       13         44  439371   160128    15663    38756   225668
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 6          4688        14686
# 31         4664        15178
# 56         4726        15112

# %%
df_gold
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 7   2017  금천구  205     0    74   240    24        50.3        8         43
# 32  2018  금천구  241     0    88   274    22        50.2       20         71
# 57  2019  금천구  213     1    67   248    20        50.3        8         60
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 7         8         26  253491    98099    11672    31750   228000
# 32       15         31  254021    98604    11541    32472   234012
# 57       16         35  251820    99150    11569    33814   242686
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 7          3318        10293
# 32         3350        11033
# 57         3435        10808

# %%
df_jung
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 24  2017  중랑구  325     1   109   309    60        50.3       13         95
# 49  2018  중랑구  280     2   106   313    32        50.8       18         67
# 74  2019  중랑구  267     2    76   256    29        51.3       10         65
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 24        9         53  412780   138184    24268    28045   102758
# 49       13         48  408147   138292    24270    28024   103016
# 74       18         47  402024   137050    24327    28228   103345
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 24         4154        10944
# 49         4152        11212
# 74         4171        11311

# %%
df_eun
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 21  2017  은평구  204     4    67   231    39        49.7       14         46
# 46  2018  은평구  213     2    81   217    32        51.3       11         50
# 71  2019  은평구  199     1    73   191    26        52.5       16         49
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 21        2         25  491202   149893    20889    24561    88818
# 46        7         41  487666   150558    20911    24873    90049
# 71        5         38  484546   150700    20880    24681    93631
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 21         4178        11781
# 46         4273        12317
# 71         4331        12965

# %%
df_seong
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 16  2017  성북구  324     2   109   341    19        48.4       16         77
# 41  2018  성북구  280     2    87   299    22        50.6       19         66
# 66  2019  성북구  294     0    74   320    28        49.2       14         77
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 16        8         37  455407   143512    26303    24039   108991
# 41       10         44  447687   142814    26271    23287   108201
# 66       14         39  454744   145865    26544    23617   111005
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 16         4415        12731
# 41         4463        13397
# 66         4461        13323

# %%
df_yong
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 20  2017  용산구  242     0    65   258    24        49.3       17         51
# 45  2018  용산구  230     3    68   212    21        50.6       18         52
# 70  2019  용산구  235     0    56   255    12        49.8       14         47
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 20        8         36  244444    93582    16124    20806   133260
# 45        7         43  245090    93531    16016    20813   141216
# 70       10         41  245185    92666    16145    20254   135240
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 20         4453        18201
# 45         4603        19474
# 70         4594        18282

# %%
df_dong
# Out:
#       년도   자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 10  2017  동대문구  295     4   115   247    19        50.3       13         70
# 35  2018  동대문구  242     3   105   221    12        49.6       13         49
# 60  2019  동대문구  210     3    61   210    15        52.5        8         51
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 10       11         40  366011   121652    24145    32411   142842
# 35       13         28  364338   122090    23766    31878   140748
# 60       12         44  363023   121637    23727    31324   138400
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 10         4909        14047
# 35         4863        14447
# 60         4845        14420

# %%
df_seo
# Out:
#       년도   자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 13  2017  서대문구  181     0    56   175    32        50.9        7         40
# 38  2018  서대문구  223     1    82   201    39        51.1        9         49
# 63  2019  서대문구  239     3    78   290    66        50.9        9         53
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 13        6         33  325028   100963    14895    19852   111117
# 38       10         37  323080   101649    14896    19796   109490
# 63        3         47  323171   101909    14805    20095   113819
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 13         4337        14107
# 38         4315        14505
# 63         4321        14232

# %%
df_moving
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 11  2017  동작구  312     4    95   298    42        47.9       22         66
# 36  2018  동작구  288     2    71   273    55        49.3       15         83
# 61  2019  동작구  293     0    94   316    49        50.7       11         67
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 11       10         35  408493   119896    15059    19966   110422
# 36       11         40  409385   120438    14962    19916   112564
# 61       17         62  408912   120628    15156    19793   106159
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 11         4143        12907
# 36         4141        13130
# 61         4153        13252

# %%
df_do
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 9   2017  도봉구  237     1    79   235    39        48.8       24         60
# 34  2018  도봉구  208     2    72   182    36        51.3       14         50
# 59  2019  도봉구  203     1    63   200    36        49.4       12         50
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 9         5         33  346234   112000    14677    18351    70503
# 34        7         36  341649   112050    14742    18894    74314
# 59       12         22  335631   111283    14848    18628    72939
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 9          2732         7514
# 34         2751         7906
# 59         2814         8203

# %%
df_sung
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 15  2017  성동구  210     1    70   187    40        49.1       15         44
# 40  2018  성동구  202     2    56   204     8        50.2       16         47
# 65  2019  성동구  185     1    47   204    14        48.0        6         45
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 15        7         33  312711   123811    20695    27278   167308
# 40        6         35  316463   126712    20618    27868   174819
# 65        7         24  308979   126428    20165    28343   178243
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 15         3786        11744
# 40         3836        12442
# 65         3935        12957

# %%
df_jjung
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 24  2017  중랑구  325     1   109   309    60        50.3       13         95
# 49  2018  중랑구  280     2   106   313    32        50.8       18         67
# 74  2019  중랑구  267     2    76   256    29        51.3       10         65
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 24        9         53  412780   138184    24268    28045   102758
# 49       13         48  408147   138292    24270    28024   103016
# 74       18         47  402024   137050    24327    28228   103345
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 24         4154        10944
# 49         4152        11212
# 74         4171        11311

# %%
df_yang
# Out:
#       년도  자치구  사고수  사망자수  중상자수  경상자수  부상자수  사고운전자_평균연령  음주운전사고수  출퇴근시간_사고수  \
# 18  2017  양천구  267     3    85   285    23        49.1       30         67
# 43  2018  양천구  225     0    64   218    30        50.8        9         51
# 68  2019  양천구  237     0    55   264    31        49.9       11         61
#
#     이륜차_사고수  고령운전자_사고수    등록인구  전체차량_대수  이륜차량_대수  전체_사업체수  전체_종사자수  \
# 18        9         31  475018   169441    18618    26077   119943
# 43        2         36  468145   169140    18608    26126   123311
# 68        6         40  462285   168528    18844    25894   121582
#
#     숙박_음식업_사업체수  숙박_음식업_종사자수
# 18         3566        11585
# 43         3604        12092
# 68         3618        12352

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 3C26-45E0
#
#  C:\Users\cityo\Desktop\Git_Space 디렉터리
#
# 2021-10-03  오후 01:16    <DIR>          .
# 2021-10-03  오후 01:16    <DIR>          ..
# 2021-10-03  오후 01:07    <DIR>          .ipynb_checkpoints
# 2021-10-03  오후 01:16         1,044,968 1002.ipynb
# 2021-10-03  오후 12:49    <DIR>          2jo
# 2021-10-03  오후 12:48    <DIR>          Algorithm
# 2021-10-03  오후 12:49    <DIR>          data-engineer-1
# 2021-10-03  오후 12:49    <DIR>          finalPJT
# 2021-10-03  오후 12:48    <DIR>          first-edition
# 2021-10-03  오후 12:49    <DIR>          github-profile-readme-generator
# 2021-10-03  오후 12:49    <DIR>          HayeonKimm
# 2021-10-03  오후 12:49    <DIR>          Hayeonkimm.github.io
# 2021-10-03  오후 12:49    <DIR>          jiyeoon
# 2021-10-03  오후 01:14    <DIR>          jupyter
# 2021-10-03  오후 12:48    <DIR>          jupyter_filizila
# 2021-10-03  오후 12:48    <DIR>          kaggle
# 2021-10-03  오후 12:48    <DIR>          Kaggle_competition
# 2021-10-03  오후 12:48    <DIR>          machine_Learning
# 2021-10-03  오후 12:48    <DIR>          multicampus_4
# 2021-10-03  오후 12:48    <DIR>          Portfolio
# 2021-10-03  오후 12:48    <DIR>          project
# 2021-07-30  오전 12:04                 0 README.md
# 2021-10-03  오후 12:49    <DIR>          southkorea-maps
# 2021-10-03  오후 12:49    <DIR>          team-meeting
# 2021-10-03  오후 12:48    <DIR>          TIL
# 2021-10-03  오후 12:49    <DIR>          Tourist_Consumption_Analysis
# 2021-10-03  오후 12:49    <DIR>          traffic-2
# 2021-09-29  오후 04:16               706 Untitled1.ipynb
# 2021-10-03  오후 12:49    <DIR>          visual-space
#                3개 파일           1,045,674 바이트
#               26개 디렉터리  218,449,166,336 바이트 남음

# %% [markdown]
# # 교통사고 데이터 분석

# %% [markdown]
# ## 강남구

# %%
df__gang=pd.read_csv('../25개자치구_사고다발데이터/교통사고_강남구.csv')

# %%
df__gang.head()
# df__gang.shape
# Out:
#      년도  월   일   요일  시각  사고등급  사망자수  중상자수  경상자수  부상자수  ... 기상상태 일광상태 사고유형1  \
# 0  2017  3   2  목요일  11  경상사고     0     0     1     0  ...   맑음   주간   차대차
# 1  2017  3   5  일요일  12  경상사고     0     0     2     0  ...   맑음   주간   차대차
# 2  2017  3  27  월요일  23  경상사고     0     0     1     0  ...   맑음   심야   차대차
# 3  2017  4  21  금요일   1  중상사고     0     2     0     0  ...   맑음   심야   차대차
# 4  2017  4  30  일요일   8  경상사고     0     0     1     0  ...   맑음  출퇴근   차대차
#
#     사고유형2     법규위반    도로종류     지점명         위도          경도  자치구
# 0    정면충돌     신호위반  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 1  측면직각충돌  안전거리미확보  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 2    정면충돌  안전운전불이행  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 3    정면충돌     신호위반  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 4    정면충돌  안전운전불이행  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
#
# [5 rows x 28 columns]

# %%
df__gang.columns
# Out:
# Index(['년도', '월', '일', '요일', '시각', '사고등급', '사망자수', '중상자수', '경상자수', '부상자수',
#        '연령', '성별', '경력', '음주', '종별', '용도', '관련자2', '사고형태', '기상상태', '일광상태',
#        '사고유형1', '사고유형2', '법규위반', '도로종류', '지점명', '위도', '경도', '자치구'],
#       dtype='object')

# %%
df_wol=df__gang['월'].value_counts()

# %%
df_wol=df_wol.columns.drop('월')

# %%
df_wol=df__gang['월'].value_counts().sort_index()

# %%
# df_wol=pd.DataFrame(df_wol,columns=['월','사고수'])

# %%
colors=['red','yellow','green','blue','pink']

# %%
df_wol.plot.bar(rot=0,color=colors)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
df_wol.plot.line()
plt.title("강남구 월 별 사고수")
plt.xlabel("월")
plt.ylabel("사고수")
# Out:
# Text(0, 0.5, '사고수')

# %%
df['년도'].count()
# Out:
# 75

# %%
df__gang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      1059 non-null   object
#  1   월       1059 non-null   int64
#  2   일       1059 non-null   int64
#  3   요일      1059 non-null   object
#  4   시각      1059 non-null   int64
#  5   사고등급    1059 non-null   object
#  6   사망자수    1059 non-null   int64
#  7   중상자수    1059 non-null   int64
#  8   경상자수    1059 non-null   int64
#  9   부상자수    1059 non-null   int64
#  10  연령      1059 non-null   object
#  11  성별      1059 non-null   object
#  12  경력      1059 non-null   object
#  13  음주      134 non-null    float64
#  14  종별      1059 non-null   object
#  15  용도      1059 non-null   object
#  16  관련자2    1059 non-null   object
#  17  사고형태    1059 non-null   object
#  18  기상상태    1059 non-null   object
#  19  일광상태    1059 non-null   object
#  20  사고유형1   1059 non-null   object
#  21  사고유형2   1059 non-null   object
#  22  법규위반    1059 non-null   object
#  23  도로종류    1059 non-null   object
#  24  지점명     1059 non-null   object
#  25  위도      1059 non-null   float64
#  26  경도      1059 non-null   float64
#  27  자치구     1059 non-null   object
# dtypes: float64(3), int64(7), object(18)
# memory usage: 231.8+ KB

# %%
df__gang['년도']=df__gang['년도'].astype(int)

# %%
df__gang
# Out:
#         년도   월   일   요일  시각  사고등급  사망자수  중상자수  경상자수  부상자수  ... 기상상태 일광상태  \
# 0     2017   3   2  목요일  11  경상사고     0     0     1     0  ...   맑음   주간
# 1     2017   3   5  일요일  12  경상사고     0     0     2     0  ...   맑음   주간
# 2     2017   3  27  월요일  23  경상사고     0     0     1     0  ...   맑음   심야
# 3     2017   4  21  금요일   1  중상사고     0     2     0     0  ...   맑음   심야
# 4     2017   4  30  일요일   8  경상사고     0     0     1     0  ...   맑음  출퇴근
# ...    ...  ..  ..  ...  ..   ...   ...   ...   ...   ...  ...  ...  ...
# 1054  2019  10  31  목요일  21  경상사고     0     0     1     0  ...   맑음   심야
# 1055  2019  11   3  일요일  15  경상사고     0     0     2     0  ...   맑음   주간
# 1056  2019  11  26  화요일  17  경상사고     0     0     1     0  ...   맑음   주간
# 1057  2019  12   3  화요일  11  경상사고     0     0     1     0  ...   맑음   주간
# 1058  2019  12   3  화요일  17  부상사고     0     0     0     1  ...   맑음   주간
#
#      사고유형1   사고유형2     법규위반    도로종류     지점명         위도          경도  자치구
# 0      차대차    정면충돌     신호위반  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 1      차대차  측면직각충돌  안전거리미확보  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 2      차대차    정면충돌  안전운전불이행  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 3      차대차    정면충돌     신호위반  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 4      차대차    정면충돌  안전운전불이행  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# ...    ...     ...      ...     ...     ...        ...         ...  ...
# 1054   차대차  차대차-기타  안전운전불이행  특별광역시도  현대백화점앞  35.866283  128.590744  강남구
# 1055   차대차  측면직각충돌     차로위반  특별광역시도  현대백화점앞  35.866283  128.590744  강남구
# 1056   차대차  측면직각충돌  안전운전불이행  특별광역시도  현대백화점앞  35.866283  128.590744  강남구
# 1057   차대차  차대차-기타  안전운전불이행  특별광역시도  현대백화점앞  35.866283  128.590744  강남구
# 1058   차대차  차대차-기타  안전거리미확보  특별광역시도  현대백화점앞  35.866283  128.590744  강남구
#
# [1059 rows x 28 columns]

# %%
plt.figure(figsize=(13,8))
df__gang['지점명'].value_counts().head(10).plot.bar(rot=30,color='green')
# Out:
# <AxesSubplot:>

# %%
df_gang_gr = df__gang.groupby(['년도',  
                                    '월'])[['사망자수','중상자수','경상자수','부상자수']].mean().reset_index()

# %%
df_gang_gr.head(1)
# Out:
#      년도  월      사망자수      중상자수     경상자수      부상자수
# 0  2017  1  0.032258  0.193548  1.16129  0.258065

# %%
plt.figure(figsize=(30,8))
# fig,ax = plt.subplots(3,3)
colors=['red','green','blue','red','purple']


plt.subplot(1,3,1)
df__gang[['사망자수','중상자수','경상자수','부상자수']].sum().plot.bar(rot=0,color=colors)
plt.subplot(1,3,2)
df__gang['사고등급'].value_counts().plot.bar(rot=0,color=colors)
plt.subplot(1,3,3)
df__gang['법규위반'].value_counts().head(4).plot.bar(rot=0,color=colors)

# %%
plt.figure(figsize=(30,5))


plt.subplot(1,3,1)
plt.title("강남구 3년간 사망자수 변화")
sns.lineplot(x='년도', y='사망자수', data=df_gang_gr,color='blue')

# plt.figure(figsize=(12,5))
plt.subplot(1,3,2)
plt.title("강남구 3년간 중상자수 변화")
sns.lineplot(x='년도', y='중상자수', data=df_gang_gr, color='red')

# plt.figure(figsize=(12,5))
plt.subplot(1,3,3)
plt.title("강남구 3년간 부상자수 변화")
sns.lineplot(x='년도', y='부상자수', data=df_gang_gr,color='green')
# Out:
# <AxesSubplot:title={'center':'강남구 3년간 부상자수 변화'}, xlabel='년도', ylabel='부상자수'>

# %% [markdown]
# ## ??

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='년도', y='사망자수', data=df__gang, hue='사고등급', ci=None)
# Out:
# <AxesSubplot:xlabel='년도', ylabel='사망자수'>

# %%
df_wol
# Out:
# 1     103
# 2      56
# 3      92
# 4     100
# 5     101
# 6     101
# 7      91
# 8      74
# 9      82
# 10     82
# 11     81
# 12     96
# Name: 월, dtype: int64

# %%
# plt.figure(figsize=(10,10))
# ax=df_wol.plot.pie()
# ax.set_title('월별 사고수')

# %%
# 1     103
# 2      56
# 3      92
# 4     100
# 5     101
# 6     101
# 7      91
# 8      74
# 9      82
# 10     82
# 11     81
# 12     96




labels = ['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월'] ## 라벨
frequency = [103,56,92,100,101,101,91,74,82,82,81,96] ## 빈도
 
colors = sns.color_palette('YlGn',len(labels)) ## 라벨의 개수 만큼 색상 리스트 생성 
 
fig = plt.figure(figsize=(10,10)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot() ## 프레임 생성
ax.set_title('월별 사고 건 수 ')

pie = ax.pie(frequency, ## 파이차트 출력
       startangle=90, ## 시작점을 90도(degree)로 지정
       counterclock=False, ## 시계 방향으로 그린다.
       autopct=lambda p : '{:.2f}%'.format(p), ## 퍼센티지 출력
       colors = colors ## 색상 지정
       )
 
plt.legend(pie[0],labels) ## 범례 표시
plt.show()

# %%
8]:
plt.figure(figsize=(12,8))
ax = df_casino.groupby('이용자 구분')['이용금액'].sum().plot.pie(figsize=(12,8))
ax.set_title('이용자 구분에 따른 이용금액 합계')

# %%
# colors=['red','green','blue','red','green','blue','red','green','blue','red','green','blue']

# # 출처: https://ehclub.net/676 [빅데이터 소스]
# # errors = [2,4,3]
# plt.bar(df_wol['월'],df_wol['사고수'],color=colors)
# plt.xlabel("월")
# plt.ylabel("사고수")
# plt.title("set yerr")
# plt.show()

# %%
df_wol2 = pd.DataFrame({'월': df_wol.index, '사고수': df_wol.values})

plt.figure(figsize=(10,6))
ax=sns.barplot(x= "월",y='사고수', data=df_wol2, palette="Spectral")
ax.set_title('월별 사고수')
# Out:
# Text(0.5, 1.0, '월별 사고수')

# %%
# ax = sns.barplot(x='월', 
# #                  y='결제건수', 
#                  data=df_wol, 
#                  palette='Spectral',
#                  ci=None)
# ax.set_title('분기별 결제건수 합계')

# %%
df__gang.head()
# Out:
#      년도  월   일   요일  시각  사고등급  사망자수  중상자수  경상자수  부상자수  ... 기상상태 일광상태 사고유형1  \
# 0  2017  3   2  목요일  11  경상사고     0     0     1     0  ...   맑음   주간   차대차
# 1  2017  3   5  일요일  12  경상사고     0     0     2     0  ...   맑음   주간   차대차
# 2  2017  3  27  월요일  23  경상사고     0     0     1     0  ...   맑음   심야   차대차
# 3  2017  4  21  금요일   1  중상사고     0     2     0     0  ...   맑음   심야   차대차
# 4  2017  4  30  일요일   8  경상사고     0     0     1     0  ...   맑음  출퇴근   차대차
#
#     사고유형2     법규위반    도로종류     지점명         위도          경도  자치구
# 0    정면충돌     신호위반  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 1  측면직각충돌  안전거리미확보  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 2    정면충돌  안전운전불이행  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 3    정면충돌     신호위반  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
# 4    정면충돌  안전운전불이행  특별광역시도  구역삼세무서  37.498266  127.030105  강남구
#
# [5 rows x 28 columns]

# %%
plt.figure(figsize=(30,8))
# fig,ax = plt.subplots(3,3)
colors=['red','green','blue','red','purple']


plt.subplot(1,3,1)
df__gang[['사망자수','중상자수','경상자수','부상자수']].sum().plot.bar(rot=0,color=colors)
plt.subplot(1,3,2)
df__gang['사고등급'].value_counts().plot.bar(rot=0,color=colors)
plt.subplot(1,3,3)
df__gang['법규위반'].value_counts().head(4).plot.bar(rot=0,color=colors)
# Out:
# <AxesSubplot:>

# %%
df__gang[['사망자수','중상자수','경상자수','부상자수']].sum().plot.bar()

# %%
df__gang['사고등급'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df__gang['법규위반'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df__gang['기상상태'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df__gang['사고유형1'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df__gang['사고유형2'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# ax = sns.barplot(x='분기', 
#                  y='결제건수', 
#                  data=df_casino_quarter, 
#                  palette='Spectral',
#                  ci=None)
# ax.set_title('분기별 결제건수 합계')
