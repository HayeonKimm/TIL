# %% [markdown]
# ## 영화DB 크롤링
#
# ### 관객 수 및 일일 수익 예측 (시계열)
# ### 문제 타깃 값 이외값들도 미지수
#
# http://www.kobis.or.kr/kobisopenapi/homepg/main/main.do

# %% [markdown]
# ----------------------

# %%
from IPython.display import Image
Image("z.png")

# %%
import requests
import json

url22 = 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20210822'
url21 = 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20210821'
url20 = 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20210820'

url_a = url20,url21,url22

# %%
# movie_text_all=[]


res = requests.get(url20)
text= res.text
    
m_20 = json.loads(text)
    

# print(movie_text)

# %%
movie_list=[]

# %%
movie_for=[]

# %%
for b in m_20['boxOfficeResult']['dailyBoxOfficeList']:
    movie_list.append(['8월 20일 영화순위 {}위 "{}" 일일 관객수: {}명, 수익: {}원'.format(b['rank'],b['movieNm'],b['audiCnt'],b['salesAmt'])])
    movie_list.append('------------------------------------------------')

# %%
# for i in url_a:
#     res = requests.get(i)
#     text= res.text
    
#     movie_text = json.loads(text)
#     movie_text_all.append(movie_text)

# %%
res = requests.get(url21)
text= res.text
    
m_21 = json.loads(text)
    

# print(movie_text)

# %%
for b in m_21['boxOfficeResult']['dailyBoxOfficeList']:
    movie_list.append(['8월 21일 영화순위 {}위 "{}" 일일 관객수: {}명, 수익: {}원'.format(b['rank'],b['movieNm'],b['audiCnt'],b['salesAmt'])])
    movie_list.append('------------------------------------------------')

# %%
res = requests.get(url22)
text= res.text
    
m_22 = json.loads(text)
    

# print(movie_text)

# %%
for b in m_22['boxOfficeResult']['dailyBoxOfficeList']:
    
    movie_list.append(['8월 22일 영화순위 {}위 "{}" 일일 관객수: {}명, 수익: {}원'.format(b['rank'],b['movieNm'],b['audiCnt'],b['salesAmt'])])
    movie_list.append('------------------------------------------------')

# %%
movie_list
# Out:
# [['8월 20일 영화순위 1위 "인질" 일일 관객수: 83905명, 수익: 835152170원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 2위 "싱크홀" 일일 관객수: 56450명, 수익: 556243680원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 3위 "모가디슈" 일일 관객수: 40282명, 수익: 377194760원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 4위 "올드" 일일 관객수: 10835명, 수익: 109165700원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 5위 "프리 가이 " 일일 관객수: 7073명, 수익: 70456050원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 6위 "퍼피 구조대 더 무비" 일일 관객수: 2880명, 수익: 24816770원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 7위 "더 수어사이드 스쿼드" 일일 관객수: 1835명, 수익: 19570510원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 8위 "팜 스프링스" 일일 관객수: 969명, 수익: 9149400원'],
#  '------------------------------------------------',
#  ['8월 20일 영화순위 9위 "남색대문" 일일 관객수: 867명, 수익: 7785400원'],
# ...

# %%
for b in m_20['boxOfficeResult']['dailyBoxOfficeList']:
    movie_for.append(['8월 20일 영화순위 {}위 "{}" 일일 관객수: {}명, 수익: {}원'.format(b['rank'],b['movieNm'],b['audiCnt'],b['salesAmt'])])
#     movie_list.append('------------------------------------------------')

for b in m_20['boxOfficeResult']['dailyBoxOfficeList']:
    movie_for.append(['8월 20일 영화순위 {}위 "{}" 일일 관객수: {}명, 수익: {}원'.format(b['rank'],b['movieNm'],b['audiCnt'],b['salesAmt'])])
#     movie_list.append('------------------------------------------------')
    
for b in m_20['boxOfficeResult']['dailyBoxOfficeList']:
    movie_for.append(['8월 20일 영화순위 {}위 "{}" 일일 관객수: {}명, 수익: {}원'.format(b['rank'],b['movieNm'],b['audiCnt'],b['salesAmt'])])
#     movie_list.append('------------------------------------------------')

# %%
import pandas as pd

# %%
df=pd.DataFrame(movie_for)

# %%
df
# Out:
#                                                     0
# 0   8월 20일 영화순위 1위 "인질" 일일 관객수: 83905명, 수익: 835152...
# 1   8월 20일 영화순위 2위 "싱크홀" 일일 관객수: 56450명, 수익: 55624...
# 2   8월 20일 영화순위 3위 "모가디슈" 일일 관객수: 40282명, 수익: 3771...
# 3   8월 20일 영화순위 4위 "올드" 일일 관객수: 10835명, 수익: 109165...
# 4   8월 20일 영화순위 5위 "프리 가이 " 일일 관객수: 7073명, 수익: 704...
# 5   8월 20일 영화순위 6위 "퍼피 구조대 더 무비" 일일 관객수: 2880명, 수익...
# 6   8월 20일 영화순위 7위 "더 수어사이드 스쿼드" 일일 관객수: 1835명, 수익...
# 7   8월 20일 영화순위 8위 "팜 스프링스" 일일 관객수: 969명, 수익: 9149...
# 8    8월 20일 영화순위 9위 "남색대문" 일일 관객수: 867명, 수익: 7785400원
# 9   8월 20일 영화순위 10위 "보스 베이비 2" 일일 관객수: 778명, 수익: 7...
# 10  8월 20일 영화순위 1위 "인질" 일일 관객수: 83905명, 수익: 835152...
# 11  8월 20일 영화순위 2위 "싱크홀" 일일 관객수: 56450명, 수익: 55624...
# 12  8월 20일 영화순위 3위 "모가디슈" 일일 관객수: 40282명, 수익: 3771...
# 13  8월 20일 영화순위 4위 "올드" 일일 관객수: 10835명, 수익: 109165...
# 14  8월 20일 영화순위 5위 "프리 가이 " 일일 관객수: 7073명, 수익: 704...
# 15  8월 20일 영화순위 6위 "퍼피 구조대 더 무비" 일일 관객수: 2880명, 수익...
# ...

# %%
# mo=movie_text_all

# %%
# url = 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=f5eef3421c602c6cb7ea224104795888&targetDt=20210821'

# %%
# movie_text = json.loads(text_all)
# print(movie_text)

# %%
for i in mo:
    print(i)

# %%
movie_list = []

for b in i['boxOfficeResult']['dailyBoxOfficeList']:
    movie_list.append(['영화순위 {}위 "{}" 일일 관객수: {}명, 수익: {}원'.format(b['rank'],b['movieNm'],b['audiCnt'],b['salesAmt'])])



# data = pd.DataFrame(movie_list)
# data.to_csv("movie_list.txt", mode='w', encoding='utf-8', index=False)

# %%
movie_list
